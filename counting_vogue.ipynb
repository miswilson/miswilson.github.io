# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time
import numpy as np
import os

# %%
import os

# %%
driver = webdriver.Chrome()
driver.get("https://archive.vogue.com/login")

# %%
start_date = pd.to_datetime("1920-01-01")
end_date = pd.to_datetime("1930-01-01")

terms = ["sequins", "glitter", "fur"]

def make_term_search(driver, term, start_date, end_date):
    url = f"https://archive.vogue.com/search?QueryTerm={term}&startDate={start_date}&endDate={end_date}"
    driver.get(url)

def get_count(driver):
    count_elements = driver.find_elements(By.CLASS_NAME, "count")
    if not count_elements:
        return None
    count_text = count_elements[0].text
    count = int(count_text.split("(")[1].split(")")[0])
    return count


increment = pd.DateOffset(years=1)
results = []
current_date = start_date

os.makedirs("vogue_resource_dump", exist_ok=True)

while current_date < end_date:
    next_date = current_date + increment
    print(f"Searching from {current_date} to {next_date}")

    make_term_search(driver, term, current_date.strftime("%Y-%m-%d"), next_date.strftime("%Y-%m-%d"))

    count = get_count(driver)
    print(f"{count} results found")

    with open(f"vogue_resource_dump/{term}_{current_date.strftime('%Y-%m-%d')}_{next_date.strftime('%Y-%m-%d')}.html", "w") as f:
        f.write(driver.page_source)

    results.append({
        "Term": term,
        "Start Date": current_date,
        "End Date": next_date,
        "Result Count": count
    })

    current_date = next_date

    # Sleep to avoid detection, ensuring non-negative sleep length
    sleep_duration = max(0, np.random.normal(1, 0.5))
    time.sleep(sleep_duration)

driver.quit()

roaring20s_df = pd.DataFrame(results)
print("Search Results Summary:")
print(roaring20s_df)
# Out:
# Searching from 1920-01-01 00:00:00 to 1921-01-01 00:00:00
# 24 results found
# Searching from 1921-01-01 00:00:00 to 1922-01-01 00:00:00
# 13 results found
# Searching from 1922-01-01 00:00:00 to 1923-01-01 00:00:00
# 4 results found
# Searching from 1923-01-01 00:00:00 to 1924-01-01 00:00:00
# 2 results found
# Searching from 1924-01-01 00:00:00 to 1925-01-01 00:00:00
# 2 results found
# Searching from 1925-01-01 00:00:00 to 1926-01-01 00:00:00
# 10 results found
# Searching from 1926-01-01 00:00:00 to 1927-01-01 00:00:00
# 25 results found
# Searching from 1927-01-01 00:00:00 to 1928-01-01 00:00:00
# 10 results found
# Searching from 1928-01-01 00:00:00 to 1929-01-01 00:00:00
# 8 results found
# Searching from 1929-01-01 00:00:00 to 1930-01-01 00:00:00
# 3 results found
# Search Results Summary:
#       Term Start Date   End Date  Result Count
# 0  sequins 1920-01-01 1921-01-01            24
# 1  sequins 1921-01-01 1922-01-01            13
# 2  sequins 1922-01-01 1923-01-01             4
# 3  sequins 1923-01-01 1924-01-01             2
# 4  sequins 1924-01-01 1925-01-01             2
# 5  sequins 1925-01-01 1926-01-01            10
# 6  sequins 1926-01-01 1927-01-01            25
# 7  sequins 1927-01-01 1928-01-01            10
# 8  sequins 1928-01-01 1929-01-01             8
# 9  sequins 1929-01-01 1930-01-01             3

# %%
print("\nSearch Results Summary:")
print(roaring20s_df.to_string(index=False))
roaring20s_df.to_csv('roaring20s_df.csv', index=False)
# Out:
# Search Results Summary:
#    Term Start Date   End Date  Result Count
# sequins 1920-01-01 1921-01-01            24
# sequins 1921-01-01 1922-01-01            13
# sequins 1922-01-01 1923-01-01             4
# sequins 1923-01-01 1924-01-01             2
# sequins 1924-01-01 1925-01-01             2
# sequins 1925-01-01 1926-01-01            10
# sequins 1926-01-01 1927-01-01            25
# sequins 1927-01-01 1928-01-01            10
# sequins 1928-01-01 1929-01-01             8
# sequins 1929-01-01 1930-01-01             3

# %%
start_date = pd.to_datetime("1920-01-01")
end_date = pd.to_datetime("1930-01-01")

term = "glitter"

def make_term_search(driver, term, start_date, end_date):
    url = f"https://archive.vogue.com/search?QueryTerm={term}&startDate={start_date}&endDate={end_date}"
    driver.get(url)

def get_count(driver):
    count_elements = driver.find_elements(By.CLASS_NAME, "count")
    if not count_elements:
        return None
    count_text = count_elements[0].text
    count = int(count_text.split("(")[1].split(")")[0])
    return count


increment = pd.DateOffset(years=1)
results = []
current_date = start_date

os.makedirs("vogue_resource_dump", exist_ok=True)

while current_date < end_date:
    next_date = current_date + increment
    print(f"Searching from {current_date} to {next_date}")

    make_term_search(driver, term, current_date.strftime("%Y-%m-%d"), next_date.strftime("%Y-%m-%d"))

    count = get_count(driver)
    print(f"{count} results found")

    with open(f"vogue_resource_dump/{term}_{current_date.strftime('%Y-%m-%d')}_{next_date.strftime('%Y-%m-%d')}.html", "w") as f:
        f.write(driver.page_source)

    results.append({
        "Term": term,
        "Start Date": current_date,
        "End Date": next_date,
        "Result Count": count
    })

    current_date = next_date

    # Sleep to avoid detection, ensuring non-negative sleep length
    sleep_duration = max(0, np.random.normal(1, 0.5))
    time.sleep(sleep_duration)

    glitter = pd.DataFrame(results)
print("Search Results Summary:")
print(glitter)

start_date = pd.to_datetime("1920-01-01")
end_date = pd.to_datetime("1930-01-01")
term = "fur"

def make_term_search(driver, term, start_date, end_date):
    url = f"https://archive.vogue.com/search?QueryTerm={term}&startDate={start_date}&endDate={end_date}"
    driver.get(url)

def get_count(driver):
    count_elements = driver.find_elements(By.CLASS_NAME, "count")
    if not count_elements:
        return None
    count_text = count_elements[0].text
    count = int(count_text.split("(")[1].split(")")[0])
    return count


increment = pd.DateOffset(years=1)
results = []
current_date = start_date

os.makedirs("vogue_resource_dump", exist_ok=True)

while current_date < end_date:
    next_date = current_date + increment
    print(f"Searching from {current_date} to {next_date}")

    make_term_search(driver, term, current_date.strftime("%Y-%m-%d"), next_date.strftime("%Y-%m-%d"))

    count = get_count(driver)
    print(f"{count} results found")

    with open(f"vogue_resource_dump/{term}_{current_date.strftime('%Y-%m-%d')}_{next_date.strftime('%Y-%m-%d')}.html", "w") as f:
        f.write(driver.page_source)

    results.append({
        "Term": term,
        "Start Date": current_date,
        "End Date": next_date,
        "Result Count": count
    })

    current_date = next_date

    # Sleep to avoid detection, ensuring non-negative sleep length
    sleep_duration = max(0, np.random.normal(1, 0.5))
    time.sleep(sleep_duration)

fur = pd.DataFrame(results)
print("Search Results Summary:")
print(fur)
# Out:
# Searching from 1920-01-01 00:00:00 to 1921-01-01 00:00:00
# 13 results found
# Searching from 1921-01-01 00:00:00 to 1922-01-01 00:00:00
# 18 results found
# Searching from 1922-01-01 00:00:00 to 1923-01-01 00:00:00
# 10 results found
# Searching from 1923-01-01 00:00:00 to 1924-01-01 00:00:00
# 7 results found
# Searching from 1924-01-01 00:00:00 to 1925-01-01 00:00:00
# 15 results found
# Searching from 1925-01-01 00:00:00 to 1926-01-01 00:00:00
# 17 results found
# Searching from 1926-01-01 00:00:00 to 1927-01-01 00:00:00
# 16 results found
# Searching from 1927-01-01 00:00:00 to 1928-01-01 00:00:00
# 15 results found
# Searching from 1928-01-01 00:00:00 to 1929-01-01 00:00:00
# 18 results found
# Searching from 1929-01-01 00:00:00 to 1930-01-01 00:00:00
# 19 results found
# Search Results Summary:
#       Term Start Date   End Date  Result Count
# 0  glitter 1920-01-01 1921-01-01            13
# 1  glitter 1921-01-01 1922-01-01            18
# 2  glitter 1922-01-01 1923-01-01            10
# 3  glitter 1923-01-01 1924-01-01             7
# 4  glitter 1924-01-01 1925-01-01            15
# 5  glitter 1925-01-01 1926-01-01            17
# 6  glitter 1926-01-01 1927-01-01            16
# 7  glitter 1927-01-01 1928-01-01            15
# 8  glitter 1928-01-01 1929-01-01            18
# 9  glitter 1929-01-01 1930-01-01            19
# Searching from 1920-01-01 00:00:00 to 1921-01-01 00:00:00
# 524 results found
# Searching from 1921-01-01 00:00:00 to 1922-01-01 00:00:00
# 622 results found
# Searching from 1922-01-01 00:00:00 to 1923-01-01 00:00:00
# 640 results found
# Searching from 1923-01-01 00:00:00 to 1924-01-01 00:00:00
# 447 results found
# Searching from 1924-01-01 00:00:00 to 1925-01-01 00:00:00
# 475 results found
# Searching from 1925-01-01 00:00:00 to 1926-01-01 00:00:00
# 530 results found
# Searching from 1926-01-01 00:00:00 to 1927-01-01 00:00:00
# 443 results found
# Searching from 1927-01-01 00:00:00 to 1928-01-01 00:00:00
# 422 results found
# Searching from 1928-01-01 00:00:00 to 1929-01-01 00:00:00
# 457 results found
# Searching from 1929-01-01 00:00:00 to 1930-01-01 00:00:00
# 437 results found
# Search Results Summary:
#   Term Start Date   End Date  Result Count
# 0  fur 1920-01-01 1921-01-01           524
# 1  fur 1921-01-01 1922-01-01           622
# 2  fur 1922-01-01 1923-01-01           640
# 3  fur 1923-01-01 1924-01-01           447
# 4  fur 1924-01-01 1925-01-01           475
# 5  fur 1925-01-01 1926-01-01           530
# 6  fur 1926-01-01 1927-01-01           443
# 7  fur 1927-01-01 1928-01-01           422
# 8  fur 1928-01-01 1929-01-01           457
# 9  fur 1929-01-01 1930-01-01           437

# %%
print(roaring20s_df)
print(fur)
print(glitter)
# Out:
#       Term Start Date   End Date  Result Count
# 0  sequins 1920-01-01 1921-01-01            24
# 1  sequins 1921-01-01 1922-01-01            13
# 2  sequins 1922-01-01 1923-01-01             4
# 3  sequins 1923-01-01 1924-01-01             2
# 4  sequins 1924-01-01 1925-01-01             2
# 5  sequins 1925-01-01 1926-01-01            10
# 6  sequins 1926-01-01 1927-01-01            25
# 7  sequins 1927-01-01 1928-01-01            10
# 8  sequins 1928-01-01 1929-01-01             8
# 9  sequins 1929-01-01 1930-01-01             3
#   Term Start Date   End Date  Result Count
# 0  fur 1920-01-01 1921-01-01           524
# 1  fur 1921-01-01 1922-01-01           622
# 2  fur 1922-01-01 1923-01-01           640
# 3  fur 1923-01-01 1924-01-01           447
# 4  fur 1924-01-01 1925-01-01           475
# 5  fur 1925-01-01 1926-01-01           530
# 6  fur 1926-01-01 1927-01-01           443
# 7  fur 1927-01-01 1928-01-01           422
# 8  fur 1928-01-01 1929-01-01           457
# 9  fur 1929-01-01 1930-01-01           437
#       Term Start Date   End Date  Result Count
# 0  glitter 1920-01-01 1921-01-01            13
# 1  glitter 1921-01-01 1922-01-01            18
# 2  glitter 1922-01-01 1923-01-01            10
# 3  glitter 1923-01-01 1924-01-01             7
# 4  glitter 1924-01-01 1925-01-01            15
# 5  glitter 1925-01-01 1926-01-01            17
# 6  glitter 1926-01-01 1927-01-01            16
# 7  glitter 1927-01-01 1928-01-01            15
# 8  glitter 1928-01-01 1929-01-01            18
# 9  glitter 1929-01-01 1930-01-01            19

# %%
fashion_20s = pd.concat([roaring20s_df, fur, glitter], ignore_index=True)
fashion_20s.to_csv('fashion_20s.csv', index=False)

# %%
print(fashion_20s)
# Out:
#        Term Start Date   End Date  Result Count
# 0   sequins 1920-01-01 1921-01-01            24
# 1   sequins 1921-01-01 1922-01-01            13
# 2   sequins 1922-01-01 1923-01-01             4
# 3   sequins 1923-01-01 1924-01-01             2
# 4   sequins 1924-01-01 1925-01-01             2
# 5   sequins 1925-01-01 1926-01-01            10
# 6   sequins 1926-01-01 1927-01-01            25
# 7   sequins 1927-01-01 1928-01-01            10
# 8   sequins 1928-01-01 1929-01-01             8
# 9   sequins 1929-01-01 1930-01-01             3
# 10      fur 1920-01-01 1921-01-01           524
# 11      fur 1921-01-01 1922-01-01           622
# 12      fur 1922-01-01 1923-01-01           640
# 13      fur 1923-01-01 1924-01-01           447
# 14      fur 1924-01-01 1925-01-01           475
# 15      fur 1925-01-01 1926-01-01           530
# 16      fur 1926-01-01 1927-01-01           443
# 17      fur 1927-01-01 1928-01-01           422
# 18      fur 1928-01-01 1929-01-01           457
# 19      fur 1929-01-01 1930-01-01           437
# 20  glitter 1920-01-01 1921-01-01            13
# 21  glitter 1921-01-01 1922-01-01            18
# 22  glitter 1922-01-01 1923-01-01            10
# 23  glitter 1923-01-01 1924-01-01             7
# 24  glitter 1924-01-01 1925-01-01            15
# 25  glitter 1925-01-01 1926-01-01            17
# 26  glitter 1926-01-01 1927-01-01            16
# 27  glitter 1927-01-01 1928-01-01            15
# 28  glitter 1928-01-01 1929-01-01            18
# 29  glitter 1929-01-01 1930-01-01            19
