# %%
# %pip install altair --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests 
import json 
import altair as alt

# %%
req = requests.get("https://www.imf.org/external/datamapper/api/v1/NGDP_RPCH/USA/CHN/GBR/EU")
data = req.json()

data
# Out:
# {'values': {'NGDP_RPCH': {'CHN': {'1980': 7.9,
#     '1981': 5.1,
#     '1982': 9,
#     '1983': 10.8,
#     '1984': 15.2,
#     '1985': 13.5,
#     '1986': 8.9,
#     '1987': 11.7,
#     '1988': 11.2,
#     '1989': 4.2,
#     '1990': 3.9,
#     '1991': 9,
#     '1992': 14.3,
#     '1993': 13.9,
#     '1994': 13,
#     '1995': 11,
#     '1996': 9.9,
#     '1997': 9.2,
#     '1998': 7.9,
#     '1999': 7.7,
#     '2000': 8.5,
#     '2001': 8.3,
#     '2002': 9.1,
#     '2003': 10,
#     '2004': 10.1,
#     '2005': 11.4,
#     '2006': 12.7,
#     '2007': 14.2,
#     '2008': 9.6,
#     '2009': 9.4,
#     '2010': 10.6,
#     '2011': 9.6,
#     '2012': 7.8,
#     '2013': 7.8,
#     '2014': 7.4,
#     '2015': 7,
#     '2016': 6.8,
#     '2017': 6.9,
#     '2018': 6.7,
#     '2019': 6,
#     '2020': 2.2,
#     '2021': 8.4,
#     '2022': 3,
#     '2023': 5.2,
#     '2024': 4.8,
#     '2025': 4.5,
#     '2026': 4.1,
#     '2027': 3.6,
#     '2028': 3.4,
#     '2029': 3.3},
# ...
