# %%
import pandas as pd

# %%
prices_df = pd.read_csv('https://eco-prices-scrapes.s3.eu-west-2.amazonaws.com/teaching/davies_price_data/db_prices.csv')
prices_df.sample(5)
# Out:
#           quote_date  shop_code  item_id_raw  region      price indicator_box  \
# 23215535    199710.0       89.0       430126     3.0  34.990002           NaN
# 15556462    200706.0       59.0       310102     9.0   2.200000           NaN
# 3489756     201402.0      814.0       211022     6.0   6.000000           NaN
# 25866604    201703.0      943.0       430358     7.0  24.990000             S
# 13980978    200701.0      107.0       220210    10.0   1.700000           NaN
#
#           item_id
# 23215535   430126
# 15556462   310102
# 3489756    211022
# 25866604   430358
# 13980978   220210

# %%
items_df = pd.read_csv('https://eco-prices-scrapes.s3.eu-west-2.amazonaws.com/teaching/davies_price_data/db_item_clean.csv')
items_df
# Out:
#       item_id                     description  date_quote_s  date_quote_e  \
# 0      210101    LARGE LOAF-WHITE-SLICED-800G        198802        200401
# 1      210102  LARGE LOAF-WHITE-UNSLICED-800G        198802        202409
# 2      210105   LARGE WHOLEMEAL LOAF-UNSLICED        198802        200301
# 3      210106     SIX BREAD ROLLS-WHITE/BROWN        198802        202409
# 4      210107     BROWN LOAF,400G,SLICED-GRAN        198903        200401
# ...       ...                             ...           ...           ...
# 1381   640233       LEISURE CENTRE MEMBERSHIP        200302        201201
# 1382   640240         LIVERY CHARGES PER WEEK        200802        202409
# 1383   640243   SOFT PLAY SESSION TIME PERIOD        201802        202409
# 1384   640244           CLIMBING WALL SESSION        202202        202409
# 1385   640406             HOTEL 1 NIGHT PRICE        200502        202409
#
#       n_obs
# 0     36039
# 1     56048
# 2     27161
# 3     65710
# 4     29361
# ...     ...
# 1381  17695
# 1382  20235
# 1383   9280
# 1384   1526
# 1385  26516
#
# [1386 rows x 5 columns]

# %%
region_df = pd.read_csv("https://eco-prices-scrapes.s3.eu-west-2.amazonaws.com/teaching/davies_price_data/db_region.csv")
region_df
# Out:
#     region_n               region_s              region           country  \
# 0          1  Catalogue collections           Catalogue               NaN
# 1          2                 London              London           England
# 2          3             South East          South East           England
# 3          4             South West          South West           England
# 4          5            East Anglia         East Anglia           England
# 5          6          East Midlands       East Midlands           England
# 6          7          West Midlands       West Midlands           England
# 7          8     Yorkshire & Humber  Yorkshire & Humber           England
# 8          9             North West          North West           England
# 9         10                  North               North           England
# 10        11                  Wales               Wales             Wales
# 11        12               Scotland            Scotland          Scotland
# 12        13       Northern Ireland    Northern Ireland  Northern Ireland
#
#         obs  p_min  p_max     p_mean  p_med        p_sd
# 0    306968   0.12   1999  41.329037  22.00   80.908554
# 1   4475848   0.01  20000  56.248341   4.60  246.010300
# 2   5785278   0.01   9499  54.609386   4.90  220.251300
# 3   3597289   0.01   6950  50.904106   4.50  201.636340
# 4   3204009   0.01   7650  51.067471   4.69  197.143280
# 5   2976879   0.01  10250  46.733604   4.07  194.929810
# 6   3518149   0.01   7650  43.581417   4.00  172.725430
# 7   3408323   0.01  20895  45.889851   4.29  183.482450
# 8   4294065   0.01   9310  42.274700   3.99  174.610350
# 9   2321737   0.01   9222  40.915108   3.99  166.738360
# 10  2216742   0.01   7347  38.699127   3.99  147.970580
# 11  3385786   0.01   7999  42.445091   4.38  168.262510
# 12  1518537   0.01   6995  44.438995   5.00  163.047960

# %% [markdown]
# </br></br>
#
# ## Merging and cleaning the data

# %%
full_df = pd.merge(prices_df, items_df[['item_id', 'description']], on='item_id') # merge prices and items
full_df
# Out:
#           quote_date  shop_code  item_id_raw  region      price indicator_box  \
# 0           199108.0        2.0       210101     2.0    0.49000           NaN
# 1           199007.0       10.0       210101    11.0    0.52000           NaN
# 2           199007.0        2.0       210101    12.0    0.37000           NaN
# 3           199811.0      179.0       210101     8.0    0.69000           NaN
# 4           199108.0        1.0       210101    10.0    0.47000           NaN
# ...              ...        ...          ...     ...        ...           ...
# 46689338    200704.0      441.0       640406     4.0   55.00000           NaN
# 46689339    200701.0      731.0       640406     3.0   85.00000           NaN
# 46689340    201210.0     5074.0       640406     3.0   40.00000           NaN
# 46689341    200812.0      542.0       640406     2.0   45.00000           NaN
# 46689342    202312.0     5084.0       640406     3.0  183.99001           NaN
#
#           item_id                   description
# 0          210101  LARGE LOAF-WHITE-SLICED-800G
# 1          210101  LARGE LOAF-WHITE-SLICED-800G
# 2          210101  LARGE LOAF-WHITE-SLICED-800G
# 3          210101  LARGE LOAF-WHITE-SLICED-800G
# 4          210101  LARGE LOAF-WHITE-SLICED-800G
# ...           ...                           ...
# 46689338   640406           HOTEL 1 NIGHT PRICE
# 46689339   640406           HOTEL 1 NIGHT PRICE
# 46689340   640406           HOTEL 1 NIGHT PRICE
# 46689341   640406           HOTEL 1 NIGHT PRICE
# 46689342   640406           HOTEL 1 NIGHT PRICE
#
# [46689343 rows x 8 columns]

# %%
full_df['quote_date'] = pd.to_datetime(full_df['quote_date'], format='%Y%m') # convert quote_date to datetime, format is yearmonth
full_df
# Out:
#          quote_date  shop_code  item_id_raw  region      price indicator_box  \
# 0        1991-08-01        2.0       210101     2.0    0.49000           NaN
# 1        1990-07-01       10.0       210101    11.0    0.52000           NaN
# 2        1990-07-01        2.0       210101    12.0    0.37000           NaN
# 3        1998-11-01      179.0       210101     8.0    0.69000           NaN
# 4        1991-08-01        1.0       210101    10.0    0.47000           NaN
# ...             ...        ...          ...     ...        ...           ...
# 46689338 2007-04-01      441.0       640406     4.0   55.00000           NaN
# 46689339 2007-01-01      731.0       640406     3.0   85.00000           NaN
# 46689340 2012-10-01     5074.0       640406     3.0   40.00000           NaN
# 46689341 2008-12-01      542.0       640406     2.0   45.00000           NaN
# 46689342 2023-12-01     5084.0       640406     3.0  183.99001           NaN
#
#           item_id                   description
# 0          210101  LARGE LOAF-WHITE-SLICED-800G
# 1          210101  LARGE LOAF-WHITE-SLICED-800G
# 2          210101  LARGE LOAF-WHITE-SLICED-800G
# 3          210101  LARGE LOAF-WHITE-SLICED-800G
# 4          210101  LARGE LOAF-WHITE-SLICED-800G
# ...           ...                           ...
# 46689338   640406           HOTEL 1 NIGHT PRICE
# 46689339   640406           HOTEL 1 NIGHT PRICE
# 46689340   640406           HOTEL 1 NIGHT PRICE
# 46689341   640406           HOTEL 1 NIGHT PRICE
# 46689342   640406           HOTEL 1 NIGHT PRICE
#
# [46689343 rows x 8 columns]

# %% [markdown]
# </br></br>
#
# # Mapping prices

# %%
items_df[items_df.description.str.contains('berries', case=False)].sort_values(by=["date_quote_e", "date_quote_s"]) # search for beer in items_df
# Out:
#      item_id                    description  date_quote_s  date_quote_e  n_obs
# 297   212706         STRAWBERRIES-PER 1/2LB        198805        199808   6333
# 318   212729      BLUEBERRIES PUNNET PER KG        201302        201801   5681
# 310   212720  STRAWBERRIES PER KG OR PUNNET        199905        202409  43508
# 321   212733   BLUEBERRIES PUNNET OR PER KG        201802        202409  33965
# 322   212734   RASPBERRIES PUNNET OR PER KG        201802        202409  31773
# 332   212809            BERRIES FROZEN PACK        202302        202409   6336

# %%
target_item_id = 212720 # STRAWBERRIES PER KG OR PUNNET

df = full_df[full_df['item_id'] == target_item_id] # filter for target item

df
# Out:
#          quote_date  shop_code  item_id_raw  region  price indicator_box  \
# 10520565 2020-06-01      119.0       212720     8.0   6.67           NaN
# 10520566 2020-04-01      807.0       212720     8.0   6.00             S
# 10520567 1999-08-01      155.0       212720     6.0   4.32           NaN
# 10520568 2021-05-01       83.0       212720    12.0   6.56           NaN
# 10520569 2019-07-01        4.0       212720     4.0   5.00             C
# ...             ...        ...          ...     ...    ...           ...
# 10564068 2012-08-01       22.0       212720     6.0   1.00           NaN
# 10564069 2023-05-01     9807.0       212720     6.0   7.60             C
# 10564070 2019-05-01      814.0       212720    10.0   8.89           NaN
# 10564071 2006-06-01       37.0       212720     3.0   6.00           NaN
# 10564072 2023-03-01       48.0       212720    11.0   2.50           NaN
#
#           item_id                    description
# 10520565   212720  STRAWBERRIES PER KG OR PUNNET
# 10520566   212720  STRAWBERRIES PER KG OR PUNNET
# 10520567   212720  STRAWBERRIES PER KG OR PUNNET
# 10520568   212720  STRAWBERRIES PER KG OR PUNNET
# 10520569   212720  STRAWBERRIES PER KG OR PUNNET
# ...           ...                            ...
# 10564068   212720  STRAWBERRIES PER KG OR PUNNET
# 10564069   212720  STRAWBERRIES PER KG OR PUNNET
# 10564070   212720  STRAWBERRIES PER KG OR PUNNET
# 10564071   212720  STRAWBERRIES PER KG OR PUNNET
# 10564072   212720  STRAWBERRIES PER KG OR PUNNET
#
# [43508 rows x 8 columns]

# %%
df['year'] = df['quote_date'].dt.year # extract year from quote_date

df = df.groupby(['year', 'region']).agg({'price': 'median'}).reset_index() # group by year and region_id, aggregate price by mean
# Out:
# <ipython-input-14-670f9ad86c95>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['quote_date'].dt.year # extract year from quote_date

# %%
region_df.region.unique()

region_codes = {
    2: "UKI",  # London
    3: "UKJ",  # South East
    4: "UKK",  # South West
    5: "UKH",  # East Anglia
    6: "UKF",  # East Midlands
    7: "UKG",  # West Midlands
    8: "UKE",  # Yorkshire & Humber
    9: "UKD",  # North West
    10: "UKC", # North
    11: "UKL", # Wales
    12: "UKM", # Scotland
    13: "UKN"  # Northern Ireland
}

df['id'] = df['region'].map(region_codes) # map region_id to region_code

df[['year', 'id', 'price']].to_csv('beer_prices_by_region.csv', index=False) # save to output.csv

# %%
df
# Out:
#      year  region  price   id
# 0    1999     2.0  4.360  UKI
# 1    1999     3.0  3.970  UKJ
# 2    1999     4.0  3.960  UKK
# 3    1999     5.0  3.950  UKH
# 4    1999     6.0  3.950  UKF
# ..    ...     ...    ...  ...
# 307  2024     9.0  7.330  UKD
# 308  2024    10.0  7.500  UKC
# 309  2024    11.0  7.465  UKL
# 310  2024    12.0  7.480  UKM
# 311  2024    13.0  7.930  UKN
#
# [312 rows x 4 columns]

# %%
blueberries_df = 212733	 # BLUEBERRIES PER KG OR PUNNET

blue = full_df[full_df['item_id'] == target_item_id] # filter for target item

blue['year'] = blue['quote_date'].dt.year # extract year from quote_date

blue = df.groupby(['year', 'region']).agg({'price': 'median'}).reset_index()

blue
# Out:
# <ipython-input-19-99efb4f702dc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   blue['year'] = blue['quote_date'].dt.year # extract year from quote_date
#      year  region  price
# 0    1999     2.0  4.360
# 1    1999     3.0  3.970
# 2    1999     4.0  3.960
# 3    1999     5.0  3.950
# 4    1999     6.0  3.950
# ..    ...     ...    ...
# 307  2024     9.0  7.330
# 308  2024    10.0  7.500
# 309  2024    11.0  7.465
# 310  2024    12.0  7.480
# 311  2024    13.0  7.930
#
# [312 rows x 3 columns]

# %%
region_df.region.unique()

region_codes = {
    2: "UKI",  # London
    3: "UKJ",  # South East
    4: "UKK",  # South West
    5: "UKH",  # East Anglia
    6: "UKF",  # East Midlands
    7: "UKG",  # West Midlands
    8: "UKE",  # Yorkshire & Humber
    9: "UKD",  # North West
    10: "UKC", # North
    11: "UKL", # Wales
    12: "UKM", # Scotland
    13: "UKN"  # Northern Ireland
}

blue['id'] = blue['region'].map(region_codes) # map region_id to region_code
blue
# Out:
#      year  region  price   id
# 0    1999     2.0  4.360  UKI
# 1    1999     3.0  3.970  UKJ
# 2    1999     4.0  3.960  UKK
# 3    1999     5.0  3.950  UKH
# 4    1999     6.0  3.950  UKF
# ..    ...     ...    ...  ...
# 307  2024     9.0  7.330  UKD
# 308  2024    10.0  7.500  UKC
# 309  2024    11.0  7.465  UKL
# 310  2024    12.0  7.480  UKM
# 311  2024    13.0  7.930  UKN
#
# [312 rows x 4 columns]

# %%
raspberries_df = 212734		 # RASPBERRIES PER KG OR PUNNET

rasp = full_df[full_df['item_id'] == target_item_id] # filter for target item

rasp['year'] = rasp['quote_date'].dt.year # extract year from quote_date

rasp = df.groupby(['year', 'region']).agg({'price': 'median'}).reset_index()

rasp
# Out:
# <ipython-input-29-9426c6a549b7>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rasp['year'] = rasp['quote_date'].dt.year # extract year from quote_date
#      year  region  price
# 0    1999     2.0  4.360
# 1    1999     3.0  3.970
# 2    1999     4.0  3.960
# 3    1999     5.0  3.950
# 4    1999     6.0  3.950
# ..    ...     ...    ...
# 307  2024     9.0  7.330
# 308  2024    10.0  7.500
# 309  2024    11.0  7.465
# 310  2024    12.0  7.480
# 311  2024    13.0  7.930
#
# [312 rows x 3 columns]

# %%
berries_df = pd.concat([blue, rasp, df], ignore_index=True)
print(berries_df)
# Out:
#      year  region  price   id
# 0    1999     2.0  4.360  UKI
# 1    1999     3.0  3.970  UKJ
# 2    1999     4.0  3.960  UKK
# 3    1999     5.0  3.950  UKH
# 4    1999     6.0  3.950  UKF
# ..    ...     ...    ...  ...
# 931  2024     9.0  7.330  UKD
# 932  2024    10.0  7.500  UKC
# 933  2024    11.0  7.465  UKL
# 934  2024    12.0  7.480  UKM
# 935  2024    13.0  7.930  UKN
#
# [936 rows x 4 columns]

# %%
blue['description'] = 'Blueberries'
rasp['description'] = 'Raspberries'
df['description'] = 'Strawberries'

berries_df = pd.concat([blue, rasp, df], ignore_index=True)
print(berries_df)
# Out:
#      year  region  price   id   description
# 0    1999     2.0  4.360  UKI   Blueberries
# 1    1999     3.0  3.970  UKJ   Blueberries
# 2    1999     4.0  3.960  UKK   Blueberries
# 3    1999     5.0  3.950  UKH   Blueberries
# 4    1999     6.0  3.950  UKF   Blueberries
# ..    ...     ...    ...  ...           ...
# 931  2024     9.0  7.330  UKD  Strawberries
# 932  2024    10.0  7.500  UKC  Strawberries
# 933  2024    11.0  7.465  UKL  Strawberries
# 934  2024    12.0  7.480  UKM  Strawberries
# 935  2024    13.0  7.930  UKN  Strawberries
#
# [936 rows x 5 columns]

# %%
berries_df.to_csv('berries_df.csv', index=False)
